# %% [markdown]
# # Exploring the Titanic Dataset

# %% [markdown]
# ### Load Data

# %%
# Define schema
from pyspark.sql.types import StructType, DoubleType, IntegerType, StringType

passenger_ticket_types = [('PassengerId',     StringType()),
                          ('Ticket',          StringType()),
                          ('Fare',            DoubleType()),
                          ('Cabin',           StringType()),
                          ('Embarked',        StringType()),
                          ('Pclass',          StringType()),
                          ('Parch',           StringType())]

passenger_demographic_types = [('PassengerId',StringType()),
                               ('Name',       StringType()),
                               ('Sex',        StringType()),
                               ('Age',        DoubleType()),
                               ('SibSp',      StringType())]

passenger_label_types = [('PassengerId',StringType()),
                         ('Survived',   IntegerType())]

# %%
from utils import create_tables

create_tables.convert_csv_to_delta(path="./data/passenger_demographics.csv", 
                                   col_types=passenger_demographic_types, 
                                   table_name="passenger_demographic_features")

create_tables.convert_csv_to_delta(path="./data/passenger_ticket.csv", 
                                   col_types=passenger_ticket_types, 
                                   table_name="passenger_ticket_features")

create_tables.convert_csv_to_delta(path="./data/passenger_labels.csv", 
                                   col_types=passenger_label_types, 
                                   table_name="passenger_labels")
# Out:
# /databricks/spark/python/pyspark/sql/pandas/conversion.py:438: UserWarning: createDataFrame attempted Arrow optimization because 'spark.sql.execution.arrow.pyspark.enabled' is set to true; however, failed by the reason below:
#   Expected a string or bytes dtype, got int64
# Attempting non-optimization as 'spark.sql.execution.arrow.pyspark.fallback.enabled' is set to true.
#   warnings.warn(msg)
# The following tables were created:
#           - passenger_demographic_features
#
# The following tables were created:
#           - passenger_ticket_features
#
# The following tables were created:
#           - passenger_labels

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# %sql
CREATE OR REPLACE VIEW titanic AS
SELECT t.PassengerId, Cabin, Fare, Pclass, Sex, Embarked, Parch, SibSp, Survived, Age
FROM passenger_ticket_features t
LEFT JOIN passenger_demographic_features d
ON d.PassengerId = t.PassengerId
LEFT JOIN passenger_labels l
ON l.PassengerId = t.PassengerId;

SELECT * FROM titanic
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PassengerId</th><th>Cabin</th><th>Fare</th><th>Pclass</th><th>Sex</th><th>Embarked</th><th>Parch</th><th>SibSp</th><th>Survived</th><th>Age</th></tr></thead><tbody><tr><td>667</td><td>NaN</td><td>13.0</td><td>2</td><td>male</td><td>S</td><td>0</td><td>0</td><td>0</td><td>25.0</td></tr><tr><td>668</td><td>NaN</td><td>7.775</td><td>3</td><td>male</td><td>S</td><td>0</td><td>0</td><td>0</td><td>NaN</td></tr><tr><td>669</td><td>NaN</td><td>8.05</td><td>3</td><td>male</td><td>S</td><td>0</td><td>0</td><td>0</td><td>43.0</td></tr><tr><td>670</td><td>C126</td><td>52.0</td><td>1</td><td>female</td><td>S</td><td>0</td><td>1</td><td>1</td><td>NaN</td></tr><tr><td>671</td><td>NaN</td><td>39.0</td><td>2</td><td>female</td><td>S</td><td>1</td><td>1</td><td>1</td><td>40.0</td></tr><tr><td>672</td><td>B71</td><td>52.0</td><td>1</td><td>male</td><td>S</td><td>0</td><td>1</td><td>0</td><td>31.0</td></tr
td><td>S</td><td>0</td><td>0</td><td>1</td><td>NaN</td></tr><tr><td>694</td><td>NaN</td><td>7.225</td><td>3</td><td>male</td><td>C</td><td>0</td><td>0</td><td>0</td><td>25.0</td></tr><tr><td>695</td><td>NaN</td><td>26.55</td><td>1</td><td>male</td><td>S</td><td>0</td><td>0</td><td>0</td><td>60.0</td></tr><tr><td>696</td><td>NaN</td><td>13.5</td><td>2</td><td>male</td><td>S</td><td>0</td><td>0</td><td>0</td><td>52.0</td></tr><tr>< ...

# %% [markdown]
# #### Clean up missing values

# %%
# %pip install bamboolib==1.30.0
# Out:
# Python interpreter will be restarted.
# Collecting bamboolib==1.30.0
#   Downloading bamboolib-1.30.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (8.0 MB)
# Requirement already satisfied: jedi<1.0.0 in /databricks/python3/lib/python3.8/site-packages (from bamboolib==1.30.0) (0.17.2)
# Collecting analytics-python==1.2.9
#   Downloading analytics_python-1.2.9-py2.py3-none-any.whl (13 kB)
# Collecting cryptography<3.0.0,>=2.6.1
#   Downloading cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7 MB)
# Collecting seaborn<0.11,>=0.10
#   Downloading seaborn-0.10.1-py3-none-any.whl (215 kB)
# Collecting ipyslickgrid==0.0.3
#   Downloading ipyslickgrid-0.0.3.tar.gz (51.4 MB)
# Collecting xlrd>=1.0.0
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Requirement already satisfied: pandas<2.0.0,>=1.1.0 in /databricks/python3/lib/python3.8/site-packages (from bamboolib==1.30.0) (1.2.4)
# Collecting ppscore<2.0.0,>=1.2.0
#   Downloading ppscore-1.2.0.tar.gz (47 kB)
# Requirement already satisfied: psutil<6,>=5.4.2 in /databricks/python3/lib/python3.8/site-packages (from bamboolib==1.30.0) (5.8.0)
# Requirement already satisfied: scikit-learn<2.0.0,>=0.20.2 in /databricks/python3/lib/python3.8/site-packages (from bamboolib==1.30.0) (0.24.1)
# Requirement already satisfied: statsmodels<1.0.0 in /databricks/python3/lib/python3.8/site-packages (from bamboolib==1.30.0) (0.12.2)
# Collecting plotly<5.0.0,>=4.9.0
#   Downloading plotly-4.14.3-py2.py3-none-any.whl (13.2 MB)
# Requirement already satisfied: ipywidgets<8.0.0,>=7.6.0 in /databricks/python3/lib/python3.8/site-packages (from bamboolib==1.30.0) (7.6.3)
# Requirement already satisfied: packaging>=19.2 in /databricks/python3/lib/python3.8/site-packages (from bamboolib==1.30.0) (21.3)
# Requirement already satisfied: attrs>=20.3.0 in /databricks/python3/lib/python3.8/site-packages (from bamboolib==1.30.0) (20.3.0)
# Collecting toml>=0.10.0
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: pygments in /databricks/python3/lib/python3.8/site-packages (from bamboolib==1.30.0) (2.8.1)
# Requirement already satisfied: requests<3.0,>=2.7 in /databricks/python3/lib/python3.8/site-packages (from analytics-python==1.2.9->bamboolib==1.30.0) (2.25.1)
# Requirement already satisfied: six>=1.5 in /databricks/python3/lib/python3.8/site-packages (from analytics-python==1.2.9->bamboolib==1.30.0) (1.15.0)
# Requirement already satisfied: python-dateutil>2.1 in /databricks/python3/lib/python3.8/site-packages (from analytics-python==1.2.9->bamboolib==1.30.0) (2.8.1)
# Requirement already satisfied: notebook>=4.0.0 in /databricks/python3/lib/python3.8/site-packages (from ipyslickgrid==0.0.3->bamboolib==1.30.0) (6.3.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /databricks/python3/lib/python3.8/site-packages (from cryptography<3.0.0,>=2.6.1->bamboolib==1.30.0) (1.14.5)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.8/site-packages (from cffi!=1.11.3,>=1.8->cryptography<3.0.0,>=2.6.1->bamboolib==1.30.0) (2.20)
# Requirement already satisfied: traitlets>=4.3.1 in /databricks/python3/lib/python3.8/site-packages (from ipywidgets<8.0.0,>=7.6.0->bamboolib==1.30.0) (5.0.5)
# Requirement already satisfied: nbformat>=4.2.0 in /databricks/python3/lib/python3.8/site-packages (from ipywidgets<8.0.0,>=7.6.0->bamboolib==1.30.0) (5.1.3)
# Requirement already satisfied: ipython>=4.0.0 in /databricks/python3/lib/python3.8/site-packages (from ipywidgets<8.0.0,>=7.6.0->bamboolib==1.30.0) (7.22.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /databricks/python3/lib/python3.8/site-packages (from ipywidgets<8.0.0,>=7.6.0->bamboolib==1.30.0) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /databricks/python3/lib/python3.8/site-packages (from ipywidgets<8.0.0,>=7.6.0->bamboolib==1.30.0) (5.3.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /databricks/python3/lib/python3.8/site-packages (from ipywidgets<8.0.0,>=7.6.0->bamboolib==1.30.0) (1.0.0)
# Requirement already satisfied: tornado>=4.2 in /databricks/python3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.6.0->bamboolib==1.30.0) (6.1)
# Requirement already satisfied: jupyter-client in /databricks/python3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.6.0->bamboolib==1.30.0) (6.1.12)
# Requirement already satisfied: backcall in /databricks/python3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib==1.30.0) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /databricks/python3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib==1.30.0) (3.0.17)
# Requirement already satisfied: pexpect>4.3 in /databricks/python3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib==1.30.0) (4.8.0)
# Requirement already satisfied: decorator in /databricks/python3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib==1.30.0) (5.0.6)
# Requirement already satisfied: pickleshare in /databricks/python3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib==1.30.0) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib==1.30.0) (52.0.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /databricks/python3/lib/python3.8/site-packages (from jedi<1.0.0->bamboolib==1.30.0) (0.7.0)
# Requirement already satisfied: jupyter-core in /databricks/python3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets<8.0.0,>=7.6.0->bamboolib==1.30.0) (4.7.1)
# Requirement already satisfied: ipython-genutils in /databricks/python3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets<8.0.0,>=7.6.0->bamboolib==1.30.0) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /databricks/python3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets<8.0.0,>=7.6.0->bamboolib==1.30.0) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /databricks/python3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8.0.0,>=7.6.0->bamboolib==1.30.0) (0.17.3)
# Requirement already satisfied: Send2Trash>=1.5.0 in /databricks/python3/lib/python3.8/site-packages (from notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib==1.30.0) (1.5.0)
# Requirement already satisfied: nbconvert in /databricks/python3/lib/python3.8/site-packages (from notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib==1.30.0) (6.0.7)
# Requirement already satisfied: terminado>=0.8.3 in /databricks/python3/lib/python3.8/site-packages (from notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib==1.30.0) (0.9.4)
# Requirement already satisfied: pyzmq>=17 in /databricks/python3/lib/python3.8/site-packages (from notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib==1.30.0) (20.0.0)
# Requirement already satisfied: jinja2 in /databricks/python3/lib/python3.8/site-packages (from notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib==1.30.0) (2.11.3)
# Requirement already satisfied: argon2-cffi in /databricks/python3/lib/python3.8/site-packages (from notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib==1.30.0) (20.1.0)
# Requirement already satisfied: prometheus-client in /databricks/python3/lib/python3.8/site-packages (from notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib==1.30.0) (0.10.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /databricks/python3/lib/python3.8/site-packages (from packaging>=19.2->bamboolib==1.30.0) (2.4.7)
# Requirement already satisfied: pytz>=2017.3 in /databricks/python3/lib/python3.8/site-packages (from pandas<2.0.0,>=1.1.0->bamboolib==1.30.0) (2020.5)
# Requirement already satisfied: numpy>=1.16.5 in /databricks/python3/lib/python3.8/site-packages (from pandas<2.0.0,>=1.1.0->bamboolib==1.30.0) (1.20.1)
# Requirement already satisfied: ptyprocess>=0.5 in /databricks/python3/lib/python3.8/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib==1.30.0) (0.7.0)
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Requirement already satisfied: wcwidth in /databricks/python3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8.0.0,>=7.6.0->bamboolib==1.30.0) (0.2.5)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.8/site-packages (from requests<3.0,>=2.7->analytics-python==1.2.9->bamboolib==1.30.0) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /databricks/python3/lib/python3.8/site-packages (from requests<3.0,>=2.7->analytics-python==1.2.9->bamboolib==1.30.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /databricks/python3/lib/python3.8/site-packages (from requests<3.0,>=2.7->analytics-python==1.2.9->bamboolib==1.30.0) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /databricks/python3/lib/python3.8/site-packages (from requests<3.0,>=2.7->analytics-python==1.2.9->bamboolib==1.30.0) (2.10)
# Requirement already satisfied: joblib>=0.11 in /databricks/python3/lib/python3.8/site-packages (from scikit-learn<2.0.0,>=0.20.2->bamboolib==1.30.0) (1.0.1)
# Requirement already satisfied: scipy>=0.19.1 in /databricks/python3/lib/python3.8/site-packages (from scikit-learn<2.0.0,>=0.20.2->bamboolib==1.30.0) (1.6.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /databricks/python3/lib/python3.8/site-packages (from scikit-learn<2.0.0,>=0.20.2->bamboolib==1.30.0) (2.1.0)
# Requirement already satisfied: matplotlib>=2.1.2 in /databricks/python3/lib/python3.8/site-packages (from seaborn<0.11,>=0.10->bamboolib==1.30.0) (3.4.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /databricks/python3/lib/python3.8/site-packages (from matplotlib>=2.1.2->seaborn<0.11,>=0.10->bamboolib==1.30.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.8/site-packages (from matplotlib>=2.1.2->seaborn<0.11,>=0.10->bamboolib==1.30.0) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /databricks/python3/lib/python3.8/site-packages (from matplotlib>=2.1.2->seaborn<0.11,>=0.10->bamboolib==1.30.0) (8.2.0)
# Requirement already satisfied: patsy>=0.5 in /databricks/python3/lib/python3.8/site-packages (from statsmodels<1.0.0->bamboolib==1.30.0) (0.5.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /databricks/python3/lib/python3.8/site-packages (from jinja2->notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib==1.30.0) (2.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /databricks/python3/lib/python3.8/site-packages (from nbconvert->notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib==1.30.0) (1.4.3)
# Requirement already satisfied: bleach in /databricks/python3/lib/python3.8/site-packages (from nbconvert->notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib==1.30.0) (3.3.0)
# Requirement already satisfied: defusedxml in /databricks/python3/lib/python3.8/site-packages (from nbconvert->notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib==1.30.0) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /databricks/python3/lib/python3.8/site-packages (from nbconvert->notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib==1.30.0) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /databricks/python3/lib/python3.8/site-packages (from nbconvert->notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib==1.30.0) (0.5.3)
# Requirement already satisfied: entrypoints>=0.2.2 in /databricks/python3/lib/python3.8/site-packages (from nbconvert->notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib==1.30.0) (0.3)
# Requirement already satisfied: jupyterlab-pygments in /databricks/python3/lib/python3.8/site-packages (from nbconvert->notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib==1.30.0) (0.1.2)
# Requirement already satisfied: testpath in /databricks/python3/lib/python3.8/site-packages (from nbconvert->notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib==1.30.0) (0.4.4)
# Requirement already satisfied: nest-asyncio in /databricks/python3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib==1.30.0) (1.5.1)
# Requirement already satisfied: async-generator in /databricks/python3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib==1.30.0) (1.10)
# Requirement already satisfied: webencodings in /databricks/python3/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.0.0->ipyslickgrid==0.0.3->bamboolib==1.30.0) (0.5.1)
# Building wheels for collected packages: ipyslickgrid, ppscore, retrying
#   Building wheel for ipyslickgrid (setup.py): started
#   Building wheel for ipyslickgrid (setup.py): finished with status 'done'
#   Created wheel for ipyslickgrid: filename=ipyslickgrid-0.0.3-py2.py3-none-any.whl size=1823270 sha256=ce1399a3e5e2b70fcb6a6357e77387ddad8fd53a68574fa45629233da545b41a
#   Stored in directory: /root/.cache/pip/wheels/ef/9b/b9/d0b565dfa32cb5e035a2e3c95cf3785b51e71787585a4e0779
#   Building wheel for ppscore (setup.py): started
#   Building wheel for ppscore (setup.py): finished with status 'done'
#   Created wheel for ppscore: filename=ppscore-1.2.0-py2.py3-none-any.whl size=13050 sha256=0af4ea4ded0a04da5539f196914471fb1931aed6397178d8f7473a68576a1941
#   Stored in directory: /root/.cache/pip/wheels/fb/0e/65/da65ce669381fc01b6ef990d301d3586991f89bff1175877a4
#   Building wheel for retrying (setup.py): started
#   Building wheel for retrying (setup.py): finished with status 'done'
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11429 sha256=1a2fcb6369c355a465728cba06c3eb9f0cdb1910de49d5ee8993b953db323cb9
#   Stored in directory: /root/.cache/pip/wheels/c4/a7/48/0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built ipyslickgrid ppscore retrying
# Installing collected packages: retrying, xlrd, toml, seaborn, ppscore, plotly, ipyslickgrid, cryptography, analytics-python, bamboolib
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.1
#     Not uninstalling seaborn at /databricks/python3/lib/python3.8/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-fa5704c8-f219-49e6-97de-5624180e5033
#     Can't uninstall 'seaborn'. No files were found to uninstall.
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.5.0
#     Not uninstalling plotly at /databricks/python3/lib/python3.8/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-fa5704c8-f219-49e6-97de-5624180e5033
#     Can't uninstall 'plotly'. No files were found to uninstall.
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 3.4.7
#     Not uninstalling cryptography at /databricks/python3/lib/python3.8/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-fa5704c8-f219-49e6-97de-5624180e5033
#     Can't uninstall 'cryptography'. No files were found to uninstall.
# Successfully installed analytics-python-1.2.9 bamboolib-1.30.0 cryptography-2.9.2 ipyslickgrid-0.0.3 plotly-4.14.3 ppscore-1.2.0 retrying-1.3.3 seaborn-0.10.1 toml-0.10.2 xlrd-2.0.1
# Python interpreter will be restarted.

# %%
import bamboolib as bam

# %%
bam
# Out:
# BamboolibModuleWindow(children=(Window(children=(VBox(children=(VBox(children=(Button(description='Databricks:…

# %%
df = spark.table("default.titanic").limit(100000).toPandas()
# Step: Drop missing values in [All columns]
df = df.dropna()

# Step: Set values of PassengerId to missing value where Cabin is one of: NaN
df.loc[df['Cabin'].isin(['NaN']), 'PassengerId'] = np.nan

# Step: Drop missing values in [All columns]
df = df.dropna()

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PassengerId</th><th>Cabin</th><th>Fare</th><th>Pclass</th><th>Sex</th><th>Embarked</th><th>Parch</th><th>SibSp</th><th>Survived</th><th>Age</th></tr></thead><tbody><tr><td>672</td><td>B71</td><td>52.0</td><td>1</td><td>male</td><td>S</td><td>0</td><td>1</td><td>0</td><td>31.0</td></tr><tr><td>680</td><td>B51 B53 B55</td><td>512.3292</td><td>1</td><td>male</td><td>C</td><td>1</td><td>0</td><td>1</td><td>36.0</td></tr><tr><td>682</td><td>D49</td><td>76.7292</td><td>1</td><td>male</td><td>C</td><td>0</td><td>0</td><td>1</td><td>27.0</td></tr><tr><td>690</td><td>B5</td><td>211.3375</td><td>1</td><td>female</td><td>S</td><td>1</td><td>0</td><td>1</td><td>15.0</td></tr><tr><td>691</td><td>B20</td><td>57.0</td><td>1</td><td>male</td><td>S</td><td>0</td><td>1</td><td>1</td><td>31.0</td></tr><tr><td>699</td><td>C68</td><td>110.8833</td><td>1</td><td>male</td><td>C</td><td>1</td><td>1</td><td>0</td><td>49.0</td></tr><tr><td>700</td><td>F G63</td><td>7.65</td><td>3</td><td>male</td><td>S</td><td>0</td><td>0</td><td>0</td><td>42.0</td></tr><tr><td>701</td><td>C62 C64</td><td>227.525</td><td>1</td><td>female</td><td>C</td><td>0</td><td>1</td><td>1</td><td>18.0</td></tr><tr><td>702</td><td>E24</td><td>26.2875</td><td>1</td><td>male</td><td>S</td><td>0</td><td>0</td><td>1</td><td>35.0</td></tr><tr><td>708</td><td>E24</td><td>26.2875</td><td>1</td><td>male</td><td>S</td><td>0</td><td>0</td><td>1</td><td>42.0</td></tr><tr><td>711</td><td>C90</td><td>49.5042</td><td>1</td><td>female</td><td>C</td><td>0</td><td>0</td><td>1</td><td>24.0</td></tr><tr><td>713</td><td>C126</td><td>52.0</td><td>1</td><td>male</td><td>S</td><td>0