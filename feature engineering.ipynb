# %% [markdown]
# ### Install Feature Engineering Library

# %%
# %pip install -r requirements.txt
# Out:
# Python interpreter will be restarted.
# Collecting git+https://github.com/RafiKurlansik/project_test.git (from -r requirements.txt (line 1))
#   Cloning https://github.com/RafiKurlansik/project_test.git to /tmp/pip-req-build-ao21bpjx
#   Running command git clone -q https://github.com/RafiKurlansik/project_test.git /tmp/pip-req-build-ao21bpjx
# Building wheels for collected packages: featurelib
#   Building wheel for featurelib (setup.py): started
#   Building wheel for featurelib (setup.py): finished with status 'done'
#   Created wheel for featurelib: filename=featurelib-0.1-py3-none-any.whl size=3103 sha256=35958f843009a15a30d38acb7461db4f8eec4422dfe12463b02a4ae1b45fc4f5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-50om_rar/wheels/76/c1/e8/dcc099a3bf75e24ab1032f73eedecc23139e2a46a68472f944
# Successfully built featurelib
# Installing collected packages: featurelib
# Successfully installed featurelib-0.1
# Python interpreter will be restarted.

# %% [markdown]
# ### Create Titanic Features

# %%
from featurelib import create_features

# %%
demographicDF = spark.sql("SELECT * FROM passenger_demographic_features")
ticketDF = spark.sql("SELECT * FROM passenger_ticket_features")

demographicFeaturesDF = create_features.compute_passenger_demographic_features(demographicDF)

ticketFeaturesDF = create_features.compute_passenger_ticket_features(ticketDF)

display(demographicFeaturesDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PassengerId</th><th>Name</th><th>Sex</th><th>Age</th><th>SibSp</th><th>NamePrefix</th><th>NameSecondary</th><th>NameMultiple</th></tr></thead><tbody><tr><td>1</td><td>Braund, Mr. Owen Harris</td><td>male</td><td>22.0</td><td>1</td><td>Mr</td><td>null</td><td>0</td></tr><tr><td>2</td><td>Cumings, Mrs. John Bradley (Florence Briggs Thayer)</td><td>female</td><td>38.0</td><td>1</td><td>Mrs</td><td>Florence Briggs Thayer</td><td>1</td></tr><tr><td>3</td><td>Heikkinen, Miss. Laina</td><td>female</td><td>26.0</td><td>0</td><td>Miss</td><td>null</td><td>0</td></tr><tr><td>4</td><td>Futrelle, Mrs. Jacques Heath (Lily May Peel)</td><td>female</td><td>35.0</td><td>1</td><td>Mrs</td><td>Lily May Peel</td><td>1</td></tr><tr><td>5</td><td>Allen, Mr. William Henry</td><td>male</td><td>35.0</td><td>0</td><td>Mr</td><td>null</td><td>0</td></tr><tr><td>6</td><td>Moran, Mr. James</td><td>male</td><td>null</td><td>0</td><td>Mr</td><td>null</td><td>0</td></tr><tr><td>7</td><td>McCarthy, Mr. Timothy J</td><td>male</td><td>54.0</td><td>0</td><td>Mr</td><td>null</td><td>0</td></tr><tr><td>8</td><td>Palsson, Master. Gosta Leonard</td><td>male</td><td>2.0</td><td>3</td><td>Master</td><td>null</td><td>0</td></tr><tr><td>9</td><td>Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg
td><td>1</td><td>13.0</td></tr><tr><td>23</td><td>8.0292</td><td>Q</td><td>3</td><td>0</td><td>null</td><td>N</td><td>1</td><td>8.0</td></tr><tr><td>24</td><td>35.5</td><td>S</td><td>1</td><td>0</td><td>null</td><td>A</td><td>1</td><td>36.0</td></tr><tr><td>25</td><td>21.075</td><td>S</td><td>3</td><td>1</td><td>null</td><td>N</td><td>1</td><td>21.0</td></tr><tr><td>26</td><td>31.3875</td><td>S</td><td>3</td><td>5</td><td>null</td><td>N</td><td>1</td><td>31.0</td></tr><tr><td>27</td><td>7.225</td><td>C</td><td>3</td><td>0</td><td>null</td><td>N</td><td>1</td><td>7.0</td></tr><tr><td>28</td><td>263.0</td><td>S</td><td>1</td><td>2</td><td>null</td><td>C</td><td>3</td><td>263.0</td></tr><tr><td>29</td><td>7.8792</td><td>Q</td><td>3</td><td>0</td><td>null</td><td>N</td><td>1</td><td>8.0</td></tr><tr><td>30</td><td>7.8958</td><td>S</td><td>3</td><td>0</td><td>null</td><td>N</td><td>1</td><td>8.0</td></tr><tr><td>31</td><td>27.7208</td><td>C</td><td>1</td><td>0</td><td>PC</td><td>N</td><td>1</td><td>28.0</td></tr><tr><td>32</td><td>146.5208</td><td>C</td><td>1</td><td>0</td><td>PC</td><td>B</td><td>1</td><td>147.0</td></tr><tr><td>33</td><td>7.75</td><td>Q</td><td>3</td><td>0</td><td>null</td><td>N</td><td>1</td><td>8.0</td></tr><tr><td>34</td><td>10.5</td><td>S</td><td>2</td><td>0</td><td>C</td><td>N</td><td>1</td><td>11.0</td ...

# %% [markdown]
# ### Write to Feature Store

# %% [markdown]
# #### Demographics

# %%
from databricks.feature_store import FeatureStoreClient

fs = FeatureStoreClient()

feature_table_name = 'default.demographic_features'

# If the feature table has already been created, no need to recreate
try:
  fs.get_table(feature_table_name)
  print("Feature table entry already exists")
  pass
  
except Exception:
  fs.create_table(name = feature_table_name,
                          primary_keys = 'PassengerId',
                          schema = demographicFeaturesDF.schema,
                          description = 'Demographic-related features for Titanic passengers')
# Out:
# 2022/03/16 21:28:29 INFO databricks.feature_store.client: Created feature table 'default.demographic_features'.

# %%
fs.write_table(
  
  name= feature_table_name,
  df = demographicFeaturesDF,
  mode = 'merge'

  )

# %% [markdown]
# #### Tickets

# %%
feature_table_name = 'default.ticket_features'

# If the feature table has already been created, no need to recreate
try:
  fs.get_table(feature_table_name)
  print("Feature table entry already exists")
  pass
  
except Exception:
  fs.create_table(name = feature_table_name,
                          primary_keys = 'PassengerId',
                          schema = ticketFeaturesDF.schema,
                          description = 'Ticket-related features for Titanic passengers')
# Out:
# 2022/03/16 21:29:20 INFO databricks.feature_store.client: Created feature table 'default.ticket_features'.

# %%
fs.write_table(
  
  name= feature_table_name,
  df = ticketFeaturesDF,
  mode = 'merge'
  
  )
